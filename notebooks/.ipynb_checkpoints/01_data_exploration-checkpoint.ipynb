# %% [markdown]
# #### 01. Image reading and data exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import SimpleITK as sitk
import os

# %matplotlib inline

# %%
print(os.getcwd())
print(os.listdir("../data/training/patient0001"))
# Out:
# /home/lars/Studie/AI4MI/camus_challenge-master/notebooks
# ['patient0001_4CH_ES.mhd:Zone.Identifier', 'patient0001_4CH_ES_gt.mhd:Zone.Identifier', 'patient0001_4CH_ES.raw:Zone.Identifier', 'patient0001_4CH_ES.mhd', 'patient0001_4CH_ED.raw', 'patient0001_2CH_sequence.raw:Zone.Identifier', 'patient0001_2CH_ED.raw', 'patient0001_2CH_ES_gt.raw:Zone.Identifier', 'patient0001_4CH_sequence.raw:Zone.Identifier', 'patient0001_4CH_sequence.raw', 'patient0001_2CH_ED_gt.mhd', 'patient0001_2CH_sequence.raw', 'patient0001_4CH_ED.raw:Zone.Identifier', 'patient0001_2CH_sequence.mhd:Zone.Identifier', 'patient0001_2CH_ES_gt.mhd:Zone.Identifier', 'patient0001_4CH_ES.raw', 'patient0001_4CH_ES_gt.raw:Zone.Identifier', 'patient0001_2CH_ES_gt.mhd', 'patient0001_4CH_ED.mhd:Zone.Identifier', 'Info_4CH.cfg:Zone.Identifier', 'patient0001_2CH_ES.mhd', 'patient0001_2CH_ED.mhd:Zone.Identifier', 'patient0001_4CH_sequence.mhd:Zone.Identifier', 'patient0001_2CH_ES.raw:Zone.Identifier', 'patient0001_2CH_sequence.mhd', 'Info_2CH.cfg', 'patient0001_4CH_ED_gt.raw', 'patient0001_4CH_ES_gt.raw', 'patient0001_2CH_ED_gt.mhd:Zone.Identifier', 'Info_2CH.cfg:Zone.Identifier', 'patient0001_2CH_ED_gt.raw', 'patient0001_2CH_ES.mhd:Zone.Identifier', 'patient0001_4CH_ES_gt.mhd', 'patient0001_4CH_ED_gt.mhd', 'patient0001_4CH_ED.mhd', 'Info_4CH.cfg', 'patient0001_2CH_ED.mhd', 'patient0001_2CH_ED_gt.raw:Zone.Identifier', 'patient0001_4CH_ED_gt.mhd:Zone.Identifier', 'patient0001_2CH_ES.raw', 'patient0001_4CH_ED_gt.raw:Zone.Identifier', 'patient0001_2CH_ED.raw:Zone.Identifier', 'patient0001_2CH_ES_gt.raw', 'patient0001_4CH_sequence.mhd']

# %%
fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 7
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

# %%
train_path = "../data/training/"

# %%
def mhd_to_array(path):
    """
    Read an *.mhd file stored in path and return it as a numpy array.
    """
    return sitk.GetArrayFromImage(sitk.ReadImage(path, sitk.sitkFloat32))

# %%
image = sitk.GetArrayFromImage(sitk.ReadImage(train_path + "patient0001/patient0001_2CH_ED.mhd", sitk.sitkFloat32))
mask = sitk.GetArrayFromImage(sitk.ReadImage(train_path + "patient0001/patient0001_2CH_ED_gt.mhd", sitk.sitkFloat32))

# %%
np.shape(image)
# Out:
# (1, 778, 549)

# %%
np.shape(mask)
# Out:
# (1, 778, 549)

# %%
fig, ax = plt.subplots(2)
ax[0].imshow(image[0]) # End Diastolic frame
ax[1].imshow(mask[0]) # End Diastolic mask
plt.show()

# %%
widths = list()
lengths = list()
patient_list = os.listdir(train_path)
for i in patient_list:
    file_list = os.listdir(os.path.join(train_path, i))
    if "mhd" in i:
        w = mhd_to_array(train_path + "/frames/" + i).shape[2]
        l = mhd_to_array(train_path + "/frames/" + i).shape[1]
        
        widths.append(w)
        lengths.append(l)
# Out:
# patient0023
# patient0115
# patient0096
# patient0457
# patient0363
# patient0158
# patient0396
# patient0037
# patient0420
# patient0100
# patient0293
# patient0262
# patient0332
# patient0370
# patient0140
# patient0489
# patient0292
# patient0325
# patient0272
# patient0010
# patient0345
# patient0294
# patient0060
# patient0350
# patient0236
# patient0052
# patient0218
# patient0077
# patient0298
# patient0409
# patient0206
# patient0275
# patient0184
# patient0011
# patient0213
# patient0033
# patient0136
# patient0467
# patient0398
# patient0302
# patient0026
# patient0059
# patient0102
# patient0344
# patient0400
# patient0214
# patient0068
# patient0137
# patient0253
# patient0329
# patient0181
# patient0366
# patient0493
# patient0235
# patient0191
# patient0401
# patient0419
# patient0164
# patient0342
# patient0305
# patient0491
# patient0179
# patient0270
# patient0312
# patient0135
# patient0202
# patient0112
# patient0040
# patient0034
# patient0147
# patient0301
# patient0234
# patient0254
# patient0280
# patient0148
# patient0440
# patient0160
# patient0494
# patient0104
# patient0088
# patient0238
# patient0223
# patient0250
# patient0129
# patient0196
# patient0108
# patient0031
# patient0264
# patient0025
# patient0170
# patient0413
# patient0086
# patient0437
# patient0081
# patient0097
# patient0047
# patient0014
# patient0391
# patient0361
# patient0113
# patient0120
# patient0216
# patient0471
# patient0030
# patient0194
# patient0003
# patient0083
# patient0093
# patient0389
# patient0397
# patient0334
# patient0149
# patient0145
# patient0367
# patient0172
# patient0163
# patient0447
# patient0462
# patient0089
# patient0099
# patient0418
# patient0427
# patient0343
# patient0321
# patient0464
# patient0352
# patient0466
# patient0415
# patient0433
# patient0444
# patient0495
# patient0417
# patient0474
# patient0429
# patient0178
# patient0476
# patient0469
# patient0143
# patient0480
# patient0180
# patient0239
# patient0075
# patient0411
# patient0475
# patient0388
# patient0430
# patient0041
# patient0355
# patient0461
# patient0032
# patient0106
# patient0024
# patient0048
# patient0222
# patient0472
# patient0362
# patient0450
# patient0035
# patient0199
# patient0459
# patient0092
# patient0171
# patient0481
# patient0055
# patient0152
# patient0359
# patient0208
# patient0402
# patient0019
# patient0304
# patient0210
# patient0183
# patient0139
# patient0076
# patient0121
# patient0278
# patient0159
# patient0189
# patient0276
# patient0383
# patient0155
# patient0110
# patient0297
# patient0174
# patient0230
# patient0015
# patient0439
# patient0130
# patient0263
# patient0314
# patient0215
# patient0484
# patient0403
# patient0029
# patient0256
# patient0442
# patient0157
# patient0307
# patient0027
# patient0182
# patient0373
# patient0045
# patient0479
# patient0105
# patient0259
# patient0394
# patient0064
# patient0266
# patient0392
# patient0338
# patient0463
# patient0107
# patient0240
# patient0142
# patient0248
# patient0412
# patient0080
# patient0069
# patient0226
# patient0423
# patient0018
# patient0404
# patient0126
# patient0071
# patient0410
# patient0369
# patient0201
# patient0365
# patient0446
# patient0470
# patient0289
# patient0084
# patient0124
# patient0330
# patient0224
# patient0382
# patient0265
# patient0498
# patient0324
# patient0246
# patient0009
# patient0357
# patient0311
# patient0490
# patient0346
# patient0281
# patient0244
# patient0406
# patient0082
# patient0103
# patient0454
# patient0375
# patient0424
# patient0053
# patient0067
# patient0188
# patient0001
# patient0434
# patient0287
# patient0229
# patient0274
# patient0177
# patient0193
# patient0374
# patient0452
# patient0062
# patient0063
# patient0354
# patient0046
# patient0020
# patient0492
# patient0431
# patient0320
# patient0319
# patient0225
# patient0123
# patient0407
# patient0074
# patient0458
# patient0043
# patient0044
# patient0268
# patient0217
# patient0291
# patient0451
# patient0209
# patient0381
# patient0286
# patient0300
# patient0017
# patient0313
# patient0151
# patient0351
# patient0376
# patient0482
# patient0279
# patient0499
# patient0316
# patient0220
# patient0008
# patient0386
# patient0131
# patient0057
# patient0288
# patient0166
# patient0331
# patient0050
# patient0150
# patient0267
# patient0449
# patient0247
# patient0203
# patient0211
# patient0497
# patient0168
# patient0242
# patient0323
# patient0134
# patient0488
# patient0207
# patient0167
# patient0341
# patient0212
# patient0252
# patient0387
# patient0036
# patient0426
# patient0091
# patient0349
# patient0356
# patient0326
# patient0432
# patient0066
# patient0485
# patient0408
# patient0348
# patient0255
# patient0021
# patient0227
# patient0333
# patient0379
# patient0249
# patient0328
# patient0176
# patient0122
# patient0306
# patient0487
# patient0260
# patient0198
# patient0221
# patient0114
# patient0360
# patient0058
# patient0237
# patient0109
# patient0445
# patient0153
# patient0233
# patient0049
# patient0006
# patient0371
# patient0353
# patient0054
# patient0117
# patient0116
# patient0144
# patient0310
# patient0393
# patient0416
# patient0282
# patient0405
# patient0257
# patient0468
# patient0277
# patient0119
# patient0258
# patient0127
# patient0243
# patient0079
# patient0186
# patient0204
# patient0022
# patient0098
# patient0118
# patient0336
# patient0377
# patient0283
# patient0455
# patient0013
# patient0290
# patient0090
# patient0378
# patient0005
# patient0187
# patient0358
# patient0335
# patient0169
# patient0042
# patient0339
# patient0251
# patient0002
# patient0478
# patient0007
# patient0231
# patient0460
# patient0414
# patient0146
# patient0380
# patient0340
# patient0271
# patient0165
# patient0364
# patient0078
# patient0190
# patient0273
# patient0285
# patient0435
# patient0128
# patient0372
# patient0141
# patient0299
# patient0185
# patient0443
# patient0441
# patient0012
# patient0421
# patient0309
# patient0395
# patient0473
# patient0016
# patient0085
# patient0133
# patient0390
# patient0051
# patient0436
# patient0138
# patient0056
# patient0095
# patient0111
# patient0422
# patient0269
# patient0327
# patient0200
# patient0125
# patient0295
# patient0070
# patient0219
# patient0453
# patient0296
# patient0399
# patient0425
# patient0496
# patient0175
# patient0245
# patient0061
# patient0261
# patient0284
# patient0385
# patient0073
# patient0315
# patient0156
# patient0317
# patient0232
# patient0483
# patient0465
# patient0438
# patient0228
# patient0197
# patient0132
# patient0161
# patient0448
# patient0087
# patient0094
# patient0384
# patient0101
# patient0368
# patient0038
# patient0028
# patient0428
# patient0318
# patient0195
# patient0192
# patient0308
# patient0322
# patient0065
# patient0154
# patient0004
# patient0241
# patient0039
# patient0162
# patient0173
# patient0347
# patient0337
# patient0500
# patient0477
# patient0456
# patient0486
# patient0205
# patient0072
# patient0303

# %%
widths = list()
lengths = list()
patient_list = os.listdir(os.path.join(train_path))
for i in patient_list:
    print(i)
    if "mhd" in i:
        w = mhd_to_array(train_path  + i).shape[2]
        l = mhd_to_array(train_path + i).shape[1]
        
        widths.append(w)
        lengths.append(l)

# %%
widhts_array = np.array(widths)
lengths_array = np.array(lengths)

plt.hist(widhts_array, bins = 15)
plt.show()
plt.hist(lengths_array, bins = 15)
plt.show()
