# %% [markdown]
# #### LadderNet training

# %%
# Standard
import os
import sys
import datetime
import numpy as np
import matplotlib.pyplot as plt

# Utils
import h5py

# Deep Learning
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

# User defined
sys.path.insert(0, "../")
from architectures.laddernet import LadderNet
from architectures.unet import UNet
from metrics.multiclass_dice import multiclass_dice
# Out:
# 2022-09-20 23:22:18.747089: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-20 23:22:18.886053: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-20 23:22:19.328007: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/lars/miniconda3/envs/ai4mi/lib/
# 2022-09-20 23:22:19.328096: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/lars/miniconda3/envs/ai4mi/lib/
# 2022-09-20 23:22:19.328101: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
f = h5py.File("../data/image_dataset.hdf5", "r")
# print(type(f["train 2ch frames"][:,:,:,:]))

# %%
frames2ch = f["train 4ch frames"][:,:,:,:]
masks2ch = f["train 4ch masks"][:,:,:,:]

# %%
print(frames2ch.shape)
# Out:
# (900, 384, 384, 1)

# %%
train_frames, test_frames, train_masks, test_masks = train_test_split(frames2ch, masks2ch)

# %%
model_laddernet = LadderNet(input_size=(384, 384, 1), num_classes=4, filters=20)
model_unet = UNet(input_size=(384, 384, 1), depth=5, num_classes=4, filters=10, batch_norm=True)
# Out:
# 2022-09-20 23:22:20.878052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:20.886832: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:20.887455: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:20.888479: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-20 23:22:20.891445: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:20.891907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:20.892315: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:22.222463: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:22.223491: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:22.223554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2022-09-20 23:22:22.224322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:09:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2022-09-20 23:22:22.224511: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8905 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:09:00.0, compute capability: 7.5

# %%
earlystop = EarlyStopping(monitor='val_multiclass_dice', min_delta=0, patience=5,
                          verbose=1, mode="max", restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor='val_multiclass_dice', factor=0.2, patience=2,
                              verbose=1, mode="max", min_lr=1e-5)

# %%
model_laddernet.compile(optimizer=Adam(lr=1e-3), loss="sparse_categorical_crossentropy", metrics=[multiclass_dice, "accuracy"])
# Out:
# /home/lars/miniconda3/envs/ai4mi/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# #### Now we are ready to train our DNN model!

# %%
model_laddernet.fit(x=train_frames,
                    y=train_masks,
                    validation_data=[test_frames, test_masks],
                    batch_size=5,
                    epochs=150,
                    callbacks=[earlystop, reduce_lr])
# Out:
# Epoch 1/150
# 2022-09-20 23:22:36.385475: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-09-20 23:22:37.174393: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-20 23:22:37.221753: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-20 23:22:37.221800: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-09-20 23:22:37.261038: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-09-20 23:22:37.261157: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#
# Epoch 26/150
# 135/135 [==============================] - 28s 209ms/step - loss: 0.1565 - multiclass_dice: 0.8030 - accuracy: 0.9357 - val_loss: 0.1688 - val_multiclass_dice: 0.7939 - val_accuracy: 0.9320 - lr: 1.0000e-05
# Epoch 27/150
# 135/135 [==============================] - 28s 209ms/step - loss: 0.1579 - multiclass_dice: 0.8018 - accuracy: 0.9354 - val_loss: 0.1684 - val_multiclass_dice: 0.7944 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 28/150
# 135/135 [==============================] - 28s 209ms/step - loss: 0.1568 - multiclass_dice: 0.8027 - accuracy: 0.9358 - val_loss: 0.1688 - val_multiclass_dice: 0.7937 - val_accuracy: 0.9320 - lr: 1.0000e-05
# Epoch 29/150
# 135/135 [==============================] - 28s 209ms/step - loss: 0.1575 - multiclass_dice: 0.8021 - accuracy: 0.9355 - val_loss: 0.1689 - val_multiclass_dice: 0.7938 - val_accuracy: 0.9319 - lr: 1.0000e-05
# Epoch 30/150
# 135/135 [==============================] - 28s 209ms/step - loss: 0.1567 - multiclass_dice: 0.8023 - accuracy: 0.9357 - val_loss: 0.1684 - val_multiclass_dice: 0.7947 - val_accuracy: 0.9321 - lr: 1.0000e-05
# Epoch 31/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1569 - multiclass_dice: 0.8027 - accuracy: 0.9358 - val_loss: 0.1683 - val_multiclass_dice: 0.7947 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 32/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1567 - multiclass_dice: 0.8022 - accuracy: 0.9357 - val_loss: 0.1686 - val_multiclass_dice: 0.7942 - val_accuracy: 0.9320 - lr: 1.0000e-05
# Epoch 33/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1570 - multiclass_dice: 0.8025 - accuracy: 0.9357 - val_loss: 0.1681 - val_multiclass_dice: 0.7948 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 34/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1567 - multiclass_dice: 0.8036 - accuracy: 0.9359 - val_loss: 0.1680 - val_multiclass_dice: 0.7949 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 35/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1577 - multiclass_dice: 0.8028 - accuracy: 0.9355 - val_loss: 0.1680 - val_multiclass_dice: 0.7947 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 36/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1566 - multiclass_dice: 0.8021 - accuracy: 0.9357 - val_loss: 0.1681 - val_multiclass_dice: 0.7945 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 37/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1562 - multiclass_dice: 0.8033 - accuracy: 0.9360 - val_loss: 0.1679 - val_multiclass_dice: 0.7950 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 38/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1567 - multiclass_dice: 0.8030 - accuracy: 0.9357 - val_loss: 0.1673 - val_multiclass_dice: 0.7952 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 39/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1560 - multiclass_dice: 0.8039 - accuracy: 0.9362 - val_loss: 0.1682 - val_multiclass_dice: 0.7945 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 40/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1563 - multiclass_dice: 0.8028 - accuracy: 0.9359 - val_loss: 0.1676 - val_multiclass_dice: 0.7953 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 41/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1565 - multiclass_dice: 0.8031 - accuracy: 0.9359 - val_loss: 0.1679 - val_multiclass_dice: 0.7944 - val_accuracy: 0.9324 - lr: 1.0000e-05
# Epoch 42/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1559 - multiclass_dice: 0.8032 - accuracy: 0.9360 - val_loss: 0.1682 - val_multiclass_dice: 0.7944 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 43/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1559 - multiclass_dice: 0.8033 - accuracy: 0.9360 - val_loss: 0.1681 - val_multiclass_dice: 0.7947 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 44/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1556 - multiclass_dice: 0.8038 - accuracy: 0.9361 - val_loss: 0.1676 - val_multiclass_dice: 0.7952 - val_accuracy: 0.9324 - lr: 1.0000e-05
# Epoch 45/150
# 135/135 [==============================] - 28s 211ms/step - loss: 0.1560 - multiclass_dice: 0.8034 - accuracy: 0.9358 - val_loss: 0.1677 - val_multiclass_dice: 0.7954 - val_accuracy: 0.9323 - lr: 1.0000e-05
# Epoch 46/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1562 - multiclass_dice: 0.8030 - accuracy: 0.9360 - val_loss: 0.1676 - val_multiclass_dice: 0.7952 - val_accuracy: 0.9324 - lr: 1.0000e-05
# Epoch 47/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1558 - multiclass_dice: 0.8037 - accuracy: 0.9361 - val_loss: 0.1679 - val_multiclass_dice: 0.7955 - val_accuracy: 0.9322 - lr: 1.0000e-05
# Epoch 48/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1555 - multiclass_dice: 0.8043 - accuracy: 0.9362 - val_loss: 0.1673 - val_multiclass_dice: 0.7953 - val_accuracy: 0.9326 - lr: 1.0000e-05
# Epoch 49/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1550 - multiclass_dice: 0.8046 - accuracy: 0.9364 - val_loss: 0.1677 - val_multiclass_dice: 0.7948 - val_accuracy: 0.9325 - lr: 1.0000e-05
# Epoch 50/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1556 - multiclass_dice: 0.8027 - accuracy: 0.9359 - val_loss: 0.1675 - val_multiclass_dice: 0.7954 - val_accuracy: 0.9326 - lr: 1.0000e-05
# Epoch 51/150
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1549 - multiclass_dice: 0.8046 - accuracy: 0.9366 - val_loss: 0.1674 - val_multiclass_dice: 0.7954 - val_accuracy: 0.9326 - lr: 1.0000e-05
# Epoch 52/150
# 135/135 [==============================] - ETA: 0s - loss: 0.1566 - multiclass_dice: 0.8025 - accuracy: 0.9356Restoring model weights from the end of the best epoch: 47.
# 135/135 [==============================] - 28s 210ms/step - loss: 0.1566 - multiclass_dice: 0.8025 - accuracy: 0.9356 - val_loss: 0.1674 - val_multiclass_dice: 0.7954 - val_accuracy: 0.9324 - lr: 1.0000e-05
# Epoch 52: early stopping

# %%
model_unet.compile(optimizer=Adam(lr=1e-3), loss="sparse_categorical_crossentropy", metrics=[multiclass_dice, "accuracy"])

# %%
model_unet.fit(x=train_frames,
                    y=train_masks,
                    validation_data=[test_frames, test_masks],
                    batch_size=5,
                    epochs=150,
                    callbacks=[earlystop, reduce_lr])
# Out:
# Epoch 1/150
# 135/135 [==============================] - 10s 55ms/step - loss: 0.8144 - multiclass_dice: 0.6389 - accuracy: 0.8433 - val_loss: 2.9314 - val_multiclass_dice: 0.3769 - val_accuracy: 0.5416 - lr: 0.0010
# Epoch 2/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.5800 - multiclass_dice: 0.7701 - accuracy: 0.9198 - val_loss: 1.2865 - val_multiclass_dice: 0.3793 - val_accuracy: 0.6739 - lr: 0.0010
# Epoch 3/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.4757 - multiclass_dice: 0.7876 - accuracy: 0.9273 - val_loss: 3.0374 - val_multiclass_dice: 0.3677 - val_accuracy: 0.4518 - lr: 0.0010
# Epoch 4/150
# 135/135 [==============================] - 7s 52ms/step - loss: 0.4003 - multiclass_dice: 0.8009 - accuracy: 0.9327 - val_loss: 0.7336 - val_multiclass_dice: 0.6248 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 5/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.3511 - multiclass_dice: 0.8010 - accuracy: 0.9337 - val_loss: 0.3785 - val_multiclass_dice: 0.7910 - val_accuracy: 0.9250 - lr: 0.0010
# Epoch 6/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.3060 - multiclass_dice: 0.8111 - accuracy: 0.9375 - val_loss: 0.3784 - val_multiclass_dice: 0.7640 - val_accuracy: 0.9135 - lr: 0.0010
# Epoch 7/150
# 135/135 [==============================] - ETA: 0s - loss: 0.2767 - multiclass_dice: 0.8125 - accuracy: 0.9384
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 135/135 [==============================] - 7s 51ms/step - loss: 0.2767 - multiclass_dice: 0.8125 - accuracy: 0.9384 - val_loss: 0.3098 - val_multiclass_dice: 0.7860 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 8/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.2436 - multiclass_dice: 0.8356 - accuracy: 0.9460 - val_loss: 0.2718 - val_multiclass_dice: 0.8043 - val_accuracy: 0.9354 - lr: 2.0000e-04
# Epoch 9/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.2315 - multiclass_dice: 0.8444 - accuracy: 0.9491 - val_loss: 0.2668 - val_multiclass_dice: 0.8014 - val_accuracy: 0.9349 - lr: 2.0000e-04
# Epoch 10/150
# 135/135 [==============================] - ETA: 0s - loss: 0.2189 - multiclass_dice: 0.8562 - accuracy: 0.9529
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 135/135 [==============================] - 7s 51ms/step - loss: 0.2189 - multiclass_dice: 0.8562 - accuracy: 0.9529 - val_loss: 0.2770 - val_multiclass_dice: 0.7960 - val_accuracy: 0.9317 - lr: 2.0000e-04
# Epoch 11/150
# 135/135 [==============================] - 7s 51ms/step - loss: 0.2035 - multiclass_dice: 0.8736 - accuracy: 0.9586 - val_loss: 0.2713 - val_multiclass_dice: 0.7958 - val_accuracy: 0.9329 - lr: 4.0000e-05
# Epoch 12/150
# 135/135 [==============================] - ETA: 0s - loss: 0.1962 - multiclass_dice: 0.8826 - accuracy: 0.9615
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1e-05.
# 135/135 [==============================] - 7s 51ms/step - loss: 0.1962 - multiclass_dice: 0.8826 - accuracy: 0.9615 - val_loss: 0.2759 - val_multiclass_dice: 0.7948 - val_accuracy: 0.9325 - lr: 4.0000e-05
# Epoch 13/150
# 135/135 [==============================] - ETA: 0s - loss: 0.1896 - multiclass_dice: 0.8907 - accuracy: 0.9641Restoring model weights from the end of the best epoch: 8.
# 135/135 [==============================] - 7s 51ms/step - loss: 0.1896 - multiclass_dice: 0.8907 - accuracy: 0.9641 - val_loss: 0.2807 - val_multiclass_dice: 0.7944 - val_accuracy: 0.9318 - lr: 1.0000e-05
# Epoch 13: early stopping

# %%
plt.imshow(train_frames[0,:,:,0])

# %%
plt.imshow(train_masks[0,:,:,0])

# %%
prediction = model_laddernet.predict(train_frames[:1,:,:,:])
# Out:
# 1/1 [==============================] - 1s 657ms/step

# %%
prediction_u = model_unet.predict(train_frames[:1,:,:,:])
# Out:
# 1/1 [==============================] - 1s 533ms/step

# %%
prediction = prediction.reshape([384, 384, 4])
prediction_u = prediction_u.reshape([384, 384, 4])
prediction.shape
# Out:
# (384, 384, 4)

# %%
import tensorflow as tf

# %%
y = tf.convert_to_tensor(prediction)
y_u = tf.convert_to_tensor(prediction_u)

# %%
z = tf.math.argmax(prediction, axis = 2)
z_u = tf.math.argmax(prediction_u, axis = 2)

# %% [markdown]
# #### Prediction visualization

# %%
plt.imshow(train_frames[0,:,:,0])

# %%
plt.imshow(train_masks[0,:,:,0])

# %%
plt.imshow(z[:,:])
plt.show()

# %%
plt.imshow(z_u[:,:])
plt.show()

# %% [markdown]
# #### Model weights storage

# %%
model_laddernet.save_weights("../models/ladder088_4ch.h5")

# %%
model_unet.save_weights("../models/unet_4ch.h5")
